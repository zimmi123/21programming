# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
source_corona =  Beautiwebpage = url='http://ncov.mohw.go.kr/'

# %%
res = requests.get(url)

# %%
source = BeautifulSoup(res.text, 'html.parser')

# %%
BeautifulSoup( Beautiwebpage, 'html.parser',from_encoding='utf-8')
# Out:
# http://ncov.mohw.go.kr/

# %%
div = source.find_all('span',{'class': 'num'})

# %%
div
# Out:
# [<span class="num"><span class="mini">(누적)</span>67,358</span>,
#  <span class="num">48,369</span>,
#  <span class="num">17,908</span>,
#  <span class="num">1,081</span>,
#  <span class="num">4,630,004 건</span>,
#  <span class="num">4,439,552 건</span>,
#  <span class="num">1.5 %</span>,
#  <span class="num">2.5</span>,
#  <span class="num">2</span>,
#  <span class="num">2</span>,
#  <span class="num">2.5</span>,
#  <span class="num">2</span>,
#  <span class="num">2</span>,
#  <span class="num">2</span>,
#  <span class="num">2</span>,
#  <span class="num">2</span>,
#  <span class="num">2</span>,
#  <span class="num">2</span>,
#  <span class="num">2</span>,
#  <span class="num">2</span>,
#  <span class="num">2</span>,
#  <span class="num">2</span>,
#  <span class="num">2</span>,
#  <span class="num">1.5</span>,
#  <span class="num">21,088</span>,
#  <span class="num">2,107</span>,
#  <span class="num">8,005</span>,
#  <span class="num">3,284</span>,
#  <span class="num">1,313</span>,
# ...

# %%
for a in div:
    print(a.get_text().strip())
# Out:
# (누적)67,358
# 48,369
# 17,908
# 1,081
# 4,630,004 건
# 4,439,552 건
# 1.5 %
# 2.5
# 2
# 2
# 2.5
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 1.5
# 21,088
# 2,107
# 8,005
# 3,284
# 1,313
# 908
# 770
# 158
# 16,508
# 1,413
# 1,348
# 1,790
# 911
# 598
# 2,625
# 1,534
# 476
# 2,522
# 67,358
# 17,908
# 48,369
# 1,081
# 129.92
# 21,088
# 8,060
# 12,805
# 223
# 216.65
# 2,107
# 482
# 1,557
# 68
# 61.76
# 8,005
# 333
# 7,469
# 203
# 328.55
# 3,284
# 775
# 2,475
# 34
# 111.09
# 1,313
# 339
# 965
# 9
# 90.14
# 908
# 128
# 772
# 8
# 61.59
# 770
# 192
# 546
# 32
# 67.13
# 158
# 20
# 137
# 1
# 46.15
# 16,508
# 4,356
# 11,826
# 326
# 124.59
# 1,413
# 349
# 1,046
# 18
# 91.72
# 1,348
# 546
# 767
# 35
# 84.28
# 1,790
# 414
# 1,349
# 27
# 84.34
# 911
# 165
# 724
# 22
# 50.13
# 598
# 78
# 514
# 6
# 32.07
# 2,625
# 393
# 2,170
# 62
# 98.59
# 1,534
# 330
# 1,199
# 5
# 45.64
# 476
# 110
# 366
# 0
# 70.97
# 2,522
# 838
# 1,682
# 2
# -

# %%
list = []
for a in div:
    list.append(a.get_text())

# %%
list
# Out:
# ['(누적)67,358',
#  '48,369',
#  '17,908',
#  '1,081',
#  '4,630,004 건',
#  '4,439,552 건',
#  '1.5 %',
#  '2.5',
#  '2',
#  '2',
#  '2.5',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1.5',
#  '21,088',
#  '2,107',
#  '8,005',
#  '3,284',
#  '1,313',
#  '908',
#  '770',
#  '158',
#  '16,508',
#  '1,413',
#  '1,348',
#  '1,790',
#  '911',
#  '598',
#  '2,625',
#  '1,534',
#  '476',
#  '2,522',
#  '67,358',
#  '17,908',
#  '48,369',
#  '1,081',
#  '129.92',
#  '21,088',
#  '8,060',
#  '12,805',
#  '223',
#  '216.65',
#  '2,107',
#  '482',
#  '1,557',
#  '68',
#  '61.76',
#  '8,005',
#  '333',
#  '7,469',
#  '203',
#  '328.55',
#  '3,284',
#  '775',
#  '2,475',
#  '34',
#  '111.09',
#  '1,313',
#  '339',
#  '965',
#  '9',
#  '90.14',
#  '908',
#  '128',
#  '772',
#  '8',
#  '61.59',
#  '770',
#  '192',
#  '546',
#  '32',
#  '67.13',
#  '158',
#  '20',
#  '137',
#  '1',
#  '46.15',
#  '16,508',
#  '4,356',
#  '11,826',
#  '326',
# ...

# %%
print('>> #오늘의 #국내 #코로나19 #현황 \n')
print('국내 유입:' ,list[0], '해외유입:' , list[1])
# Out:
# >> #오늘의 #국내 #코로나19 #현황
#
# 국내 유입: (누적)67,358 해외유입: 48,369
